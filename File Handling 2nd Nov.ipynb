# %%
myfile = open('/content/File Handling.txt')

# %%
myfile.read()
# Out:
# 'My name is Ankur Arora \nI currently live in Pune\nI am here to teach DS.'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'My name is Ankur Arora \nI currently live in Pune\nI am here to teach DS.'

# %%
myfile.seek(10)
# Out:
# 10

# %%
myfile.read()
# Out:
# ' Ankur Arora \nI currently live in Pune\nI am here to teach DS.'

# %%
myfile.close()

# %%
myfile.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f51008fa62ae> in <cell line: 1>()
# ----> 1 myfile.read()
#
# ValueError: I/O operation on closed file.

# %%
myfile = open('/content/File Handling.txt','w+')  #w+ for overwriting the content

# %%
myfile.read()
# Out:
# ''

# %%
myfile.write("I learn Datascience")
# Out:
# 19

# %%
myfile.close()

# %%
myfile = open('/content/File Handling.txt','w+')

# %%
myfile.close()

# %%
myfile = open('/content/File Handling.txt','w+')

# %%
myfile.write("I Learn datascience")
# Out:
# 19

# %%
myfile.close()

# %%
myfile = open('/content/File Handling.txt','a+')

# %%
myfile.read()
# Out:
# ''

# %%
myfile.write("My name is shamik chitale")
# Out:
# 25

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'I Learn datascienceMy name is shamik chitale'

# %%
myfile.seek(9)
# Out:
# 9

# %%
myfile.write("I live in pune")
# Out:
# 14

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'I Learn datascienceMy name is shamik chitaleI live in pune'

# %%
test = open('/content/test.txt','w+')

# %%
test.write("This is my test file")
# Out:
# 20

# %%
test.close()
